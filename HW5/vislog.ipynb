# %% [markdown]
# # Plotting of Experimenmt Results

# %% [markdown]
# Instructions:
# - Replace your AWS credentials
# - Specify the name of your S3 bucket
# - Print available experiemnt clusters to download locally
# - Pick your experiment cluster to plot
# - Pick which experiments in the cluster to plot
# - Make your plots
# - Analyze!

# %% [markdown]
# ## Imports

# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\nickc\anaconda3\lib\site-packages (1.37.25)
# Requirement already satisfied: botocore<1.38.0,>=1.37.25 in c:\users\nickc\anaconda3\lib\site-packages (from boto3) (1.37.25)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\nickc\anaconda3\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\nickc\anaconda3\lib\site-packages (from boto3) (0.11.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\nickc\anaconda3\lib\site-packages (from botocore<1.38.0,>=1.37.25->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\nickc\anaconda3\lib\site-packages (from botocore<1.38.0,>=1.37.25->boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\nickc\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.25->boto3) (1.16.0)

# %%
import matplotlib.pyplot as plt
import os
import boto3
import numpy as np

# %% [markdown]
# ## Parsing functions

# %%
def parse_logfile(logfile):
    # so the tricky part we have to deal with in these log files
    # is that the job could crash and get restarted, which will
    # re-wind back and start re-logging older steps. So we keep
    # all the data as dictionary and over-write old data with new
    # and then at the end compile everything together

    # read raw data
    streams = {} # stream:str -> {step: val}
    lrs = {}
    total_training_time = 0
    with open(logfile, "r") as f:
        for line in f:
            parts = line.split()
            step = int(parts[0].split(":")[1])
            stream = parts[1].split(":")[0]
            val = float(parts[1].split(":")[1])
            if not stream in streams:
                streams[stream] = {}
            d = streams[stream]
            d[step] = val
            
            if len(parts) > 2:
                lr = float(parts[2].split(":")[1])
                lrs[step] = lr
                
                try:
                    time = float(parts[5].split(":")[1])
                    total_training_time += time / 1000 # convert from ms to s
                except:
                    pass


    # now re-represent as list of (step, val) tuples
    streams_xy = {}
    for k, v in streams.items():
        # get all (step, val) items, sort them
        xy = sorted(list(v.items()))
        # unpack the list of tuples to tuple of lists
        streams_xy[k] = zip(*xy)
    # return the xs, ys lists

    # convert total train time from s to hours
    total_training_time /= 3600

    return streams_xy, (np.array(list(lrs.keys())), np.array(list(lrs.values()))), total_training_time

# optional function that smooths out the loss some
def smooth_moving_average(signal, window_size):
    if signal.ndim != 1:
        raise ValueError("smooth_moving_average only accepts 1D arrays.")
    if signal.size < window_size:
        raise ValueError("Input vector needs to be bigger than window size.")
    if window_size < 3:
        return signal

    s = np.pad(signal, (window_size//2, window_size-1-window_size//2), mode='edge')
    w = np.ones(window_size) / window_size
    smoothed_signal = np.convolve(s, w, mode='valid')
    return smoothed_signal

# %%
def extract_learning_rate(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Check if the line contains the learning rate parameter
                if 'learning rate (LR)' in line:
                    # Split the line and extract the value
                    parts = line.split('|')
                    learning_rate = parts[2].strip()  # The value is in the 3rd part
                    return float(learning_rate)  # Convert to float for numerical use

    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return None  # Return None if the learning rate is not found

def extract_parameters(file_path):
    num_parameters = None    
    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Check if the line contains the number of parameters
                if 'num_parameters' in line:
                    # Split the line and extract the value
                    parts = line.split('|')
                    num_parameters = int(parts[2].strip())  # Convert to int

                if num_parameters is not None:
                    break

    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return num_parameters  # Return both values

# %% [markdown]
# ## AWS Credentials

# %%
# TODO: Replace with your IAM User credentials
aws_access_key = "AKIAUQ4L2ZROSQ4UQKBO"
aws_secret_key = "CfVw+U930tzRPwzM5d5l/tB/QlWQ3rLxEC6t0cAD"
aws_region = "us-east-1"  # Replace with the region that your s3 bucket is in, is normally just us-east-1

# %% [markdown]
# ## Getting your logs from the S3 Bucket

# %%
# Create a boto3 session with your credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key,
    region_name=aws_region
)

# Create an S3 client or resource with this session
s3_client = session.client('s3')
s3 = session.resource('s3')

# %%
# TODO: Specify your bucket
bucket_name = "10605nchermakhw5"

# %% [markdown]
# # Print Available Experiment Clusters

# %%
# Get the S3 bucket
bucket = s3.Bucket(bucket_name)

# Set to store unique top-level folder names
folders = set()

# List folders inside the experiments folder
experiments_folder = "experiments/"
for obj in bucket.objects.filter(Prefix=experiments_folder):
    # Extract the folder name after 'experiments/' by splitting on '/'
    parts = obj.key[len(experiments_folder):].split('/')
    if len(parts) > 1:
        folder_name = parts[0]
        folders.add(folder_name)

# Print all unique top-level folders
print("Experiment Clusters that you can plot:")
for folder in sorted(folders):
    print('\t-', folder)
# Out:
# Experiment Clusters that you can plot:
# 	- full_gpt
# 	- question_1_experiments
# 	- question_2_strat3

# %% [markdown]
# ## Getting your experiment logs
#
# To download your logs, specify the **cluster_name** variable to the experiment cluster you want to download then run the next cell. This downloads this experiment cluster and saves it locally in a folder in the current working directory called downloaded_logs

# %%
# TODO: Specify which experiment cluster you want to download and then plot.
cluster_name = "full_gpt"

# %%
# Define the local directory to save files
local_directory = os.path.join(os.getcwd(), "downloaded_logs")
os.makedirs(local_directory, exist_ok=True)

# Download files in the specified subfolder
for obj in bucket.objects.filter(Prefix=f"{experiments_folder}{cluster_name}/"):
    # Define the local path to save the file
    relative_path = os.path.relpath(obj.key, experiments_folder)
    local_file_path = os.path.join(local_directory, relative_path)

    # Create local directories if they do not exist
    os.makedirs(os.path.dirname(local_file_path), exist_ok=True)

    # Download the file
    print(f"Downloading {obj.key} to {local_file_path}")
    bucket.download_file(obj.key, local_file_path)

print("Download complete.")
# Out:
# Downloading experiments/full_gpt/logGPT/main.log to c:\Users\nickc\Downloads\S25_HW5-hw5 (1)\S25_HW5-hw5\downloaded_logs\full_gpt\logGPT\main.log
# Downloading experiments/full_gpt/logGPT/run_parameters.txt to c:\Users\nickc\Downloads\S25_HW5-hw5 (1)\S25_HW5-hw5\downloaded_logs\full_gpt\logGPT\run_parameters.txt
# Download complete.

# %% [markdown]
# # Printing the individual experiments within your cluster

# %%
# List all entries in the specified directory
path = os.path.join('downloaded_logs', cluster_name)

print("Available individual experiments to plot")
for entry in os.listdir(path):
    # Check if the entry is a directory
    if os.path.isdir(os.path.join(path, entry)):
        print('\t-', entry)
# Out:
# Available individual experiments to plot
# 	- logGPT

# %% [markdown]
# Specify which individual experiments from the cluster you would like to plot. Leave the variable **experiments_to_plot** as an empty list if you want to plot all experiments in the cluster.

# %%
# TODO: Specify which experiments you want to plot. Leave empty is if you want to plot all experiments in the cluster
# experiments_to_plot = ["question_2_tiny_1",
#                         "question_2_tiny_2",
#                         "question_2_tiny_3",
#                         "question_2_tiny_4",
#                         "question_2_tiny_5",
#                         "question_2_tiny_6",
#                         "question_2_tiny_7",
#                         "question_2_tiny_8",
#                         "question_2_tiny_9",
#                         "question_2_tiny_10",
#                         "question_2_tiny_11",
#                         "question_2_tiny_12",
#                         "question_2_tiny_13"]

# experiments_to_plot = ["question_2_tinier_1",
#                         "question_2_tinier_2",
#                         "question_2_tinier_3",
#                         "question_2_tinier_4",
#                         "question_2_tinier_5",
#                         "question_2_tinier_6",
#                         "question_2_tinier_7",
#                         "question_2_tinier_8",
#                         "question_2_tinier_9",
#                         "question_2_tinier_10",
#                         "question_2_tinier_11",
#                         "question_2_tinier_12",
#                         "question_2_tinier_13",
#                         "question_2_tinier_14"]

# experiments_to_plot = ["question_2_tiniest_1",
#                         "question_2_tiniest_2",
#                         "question_2_tiniest_3",
#                         "question_2_tiniest_4",
#                         "question_2_tiniest_5",
#                         "question_2_tiniest_6",
#                         "question_2_tiniest_7",
#                         "question_2_tiniest_8",
#                         "question_2_tiniest_9",
#                         "question_2_tiniest_10",
#                         "question_2_tiniest_11",
#                         "question_2_tiniest_12"]

experiments_to_plot = []

# %% [markdown]
# ## Plot your experiment

# %%
def plot_experiment(cluster_name, to_plot, plot_val_loss=True, plot_train_loss=False, draw_min_train_loss=False, draw_min_val_loss=False):
    plt.figure(figsize=(16, 4))

    cluster_path = os.path.join(local_directory, cluster_name)

    # Check if the experiment path exists and is a directory

    
    if len(to_plot) == 0:
        # plot all experiments in the cluster
        directory_list = [item for item in os.listdir(cluster_path)]
    else:
        directory_list = [os.path.join(cluster_path, item) for item in to_plot]

    for item in directory_list:
        item_path = os.path.join(cluster_path, item)
        if os.path.isdir(item_path):
            # print('\t', f'Adding {item_path} to plot')

            logfile = os.path.join(item_path, "main.log")

            param_file = os.path.join(item_path, "run_parameters.txt")
            learn_rate = extract_learning_rate(param_file)
            num_params = extract_parameters(param_file) / 1e6 # convert to millions

            name = f'LR: {learn_rate}'

            streams, lr_data, train_time = parse_logfile(logfile)
            steps, lr_val = lr_data

            # Panel 1: losses: both train and val
            plt.subplot(131)
            xs1, ys1 = streams["trl"] # training loss
            ys1 = np.array(ys1)

            # smooth out ys using a rolling window
            # ys = smooth_moving_average(ys, 21) # optional

            xs2, ys2 = streams["tel"] # validation loss

            if draw_min_train_loss:
                plt.axhline(min(ys1), color='b', linestyle='--')
            if draw_min_val_loss:
                plt.axhline(min(ys2), color='r', linestyle='--')

            if plot_train_loss:
                plt.plot(xs1, ys1, label=f'({name}) train loss')

            if plot_val_loss:
                plt.plot(xs2, ys2, label=f'({name}) val loss')
            
            if num_params is not None and learn_rate is not None:
                print(f"Params: {num_params:.2f}m | LR : {learn_rate:.6f} | Min Train Loss: {min(ys1):.4f} | Min Val Loss : {min(ys2):.4f} | Train Time : {train_time:.2f} hrs")
            else:
                print(f"Min Train Loss: {min(ys)}")
            
            plt.xlabel("steps")
            plt.ylabel("loss")
            plt.yscale('log')
            plt.legend()
            plt.title("Loss")

            plt.subplot(132)
            if "eval" in streams:
                xs, ys = streams["eval"] # HellaSwag eval
                ys = np.array(ys)
                plt.plot(xs, ys, label=f"({name})")

                plt.xlabel("steps")
                plt.ylabel("accuracy")
                plt.legend()
                plt.title("HellaSwag eval")
                # print("Max Hellaswag eval:", max(ys))

            plt.subplot(133)
            plt.plot(steps, lr_val)
            plt.title("Learning Rate Schedule")
            plt.xlabel("steps")
            plt.ylabel("learning rate")

    plt.show()

# %% [markdown]
# The **plot_experiments** takes the following inputs:
#   - name of a cluster to plot (You must have downlaoded the cluster logs in order for the plotting to work)
#   - a list containing the experiments you want to plot (leave empty if you want to plot them all)
#   - two booleans for if you want to plot validation loss or training loss
#   - a boolean for if you want to label the plots by the learning rate they used
#     - if set to False, then it will default to using the experiment name (folder name)
#
# It will print the minimum training loss and minimum validation loss achieved for each experiment, along with the total number of parameters and learning rate used.

# %%
plot_experiment(cluster_name, experiments_to_plot, 
                plot_val_loss=False, 
                plot_train_loss=True, 
                draw_min_train_loss=True,
                draw_min_val_loss=False)
# Out:
# Params: 124.48m | LR : 0.006398 | Min Train Loss: 3.2933 | Min Val Loss : 3.4097 | Train Time : 11.07 hrs

# %% [markdown]
# # Analysis
#
# Do any of your analysis here, or keep tables of models you've already tested!
#
# | Example | of | a | table |
# | --- | --- | --- | --- |
# | this | is | a | row |
# | and | this | is | also |

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def plot_final(cluster_name, to_plot, plot_val_loss=True, plot_train_loss=False, draw_min_train_loss=False, draw_min_val_loss=False):
    plt.figure(figsize=(16, 4))

    cluster_path = os.path.join(local_directory, cluster_name)

    if len(to_plot) == 0:
        # plot all experiments in the cluster
        directory_list = [item for item in os.listdir(cluster_path)]
    else:
        directory_list = [os.path.join(cluster_path, item) for item in to_plot]

    for item in directory_list:
        item_path = os.path.join(cluster_path, item)
        if os.path.isdir(item_path):
            logfile = os.path.join(item_path, "main.log")

            param_file = os.path.join(item_path, "run_parameters.txt")
            learn_rate = extract_learning_rate(param_file)
            num_params = extract_parameters(param_file) / 1e6  # convert to millions

            name = f'LR: {learn_rate}'

            streams, lr_data, train_time = parse_logfile(logfile)
            steps, lr_val = lr_data

            # Panel 1: losses
            plt.subplot(131)
            xs1, ys1 = streams["trl"]  # training loss
            ys1 = np.array(ys1)

            xs2, ys2 = streams["tel"]  # validation loss
            ys2 = np.array(ys2)

            if draw_min_train_loss:
                plt.axhline(min(ys1), color='b', linestyle='--')
            if draw_min_val_loss:
                plt.axhline(min(ys2), color='r', linestyle='--')

            if plot_train_loss:
                plt.plot(xs1, ys1, label=f'({name}) train loss')

            if plot_val_loss:
                plt.plot(xs2, ys2, label=f'({name}) val loss')

            if num_params is not None and learn_rate is not None:
                print(f"Params: {num_params:.10f}m | LR : {learn_rate:.11f} | Min Train Loss: {min(ys1):.4f} | Min Val Loss : {min(ys2):.4f} | Train Time : {train_time:.2f} hrs")
            else:
                print(f"Min Train Loss: {min(ys1)}")

            final_val_loss = ys2[-1]
            print(f"Final Validation Loss: {final_val_loss:.4f}")

            plt.xlabel("steps")
            plt.ylabel("loss")
            plt.yscale('log')
            plt.legend()
            plt.title("Loss")

            # Panel 2: eval (HellaSwag)
            plt.subplot(132)
            if "eval" in streams:
                xs, ys = streams["eval"]
                ys = np.array(ys)
                plt.plot(xs, ys, label=f"({name})")

                final_accuracy = ys[-1]
                print(f"Final HellaSwag Accuracy: {final_accuracy:.4f}")

                plt.xlabel("steps")
                plt.ylabel("accuracy")
                plt.legend()
                plt.title("HellaSwag eval")

            # Panel 3: learning rate
            plt.subplot(133)
            plt.plot(steps, lr_val)
            plt.title("Learning Rate Schedule")
            plt.xlabel("steps")
            plt.ylabel("learning rate")

    plt.show()

# %%
plot_final(cluster_name, experiments_to_plot, 
                plot_val_loss=False, 
                plot_train_loss=True, 
                draw_min_train_loss=True,
                draw_min_val_loss=False)
# Out:
# Params: 6.9667840000m | LR : 0.00043269280 | Min Train Loss: 5.9156 | Min Val Loss : 6.0985 | Train Time : 0.19 hrs
# Final Validation Loss: 6.0985
# Final HellaSwag Accuracy: 0.2433
# Params: 6.9667840000m | LR : 0.00038177180 | Min Train Loss: 5.9731 | Min Val Loss : 6.1600 | Train Time : 0.19 hrs
# Final Validation Loss: 6.1600
# Final HellaSwag Accuracy: 0.2433
# Params: 6.9667840000m | LR : 0.01001156000 | Min Train Loss: 5.4892 | Min Val Loss : 5.6263 | Train Time : 0.19 hrs
# Final Validation Loss: 5.6263
# Final HellaSwag Accuracy: 0.2394
# Params: 6.9667840000m | LR : 0.00022788330 | Min Train Loss: 6.1994 | Min Val Loss : 6.3929 | Train Time : 0.19 hrs
# Final Validation Loss: 6.3929
# Final HellaSwag Accuracy: 0.2464
# Params: 6.9667840000m | LR : 0.00622029800 | Min Train Loss: 4.9782 | Min Val Loss : 5.1118 | Train Time : 0.19 hrs
# Final Validation Loss: 5.1118
# Final HellaSwag Accuracy: 0.2471
# Params: 6.9667840000m | LR : 0.00111005000 | Min Train Loss: 5.4614 | Min Val Loss : 5.6162 | Train Time : 0.19 hrs
# Final Validation Loss: 5.6162
# Final HellaSwag Accuracy: 0.2406
# Params: 6.9667840000m | LR : 0.00046068160 | Min Train Loss: 5.8865 | Min Val Loss : 6.0665 | Train Time : 0.19 hrs
# Final Validation Loss: 6.0665
# Final HellaSwag Accuracy: 0.2408
# Params: 6.9667840000m | LR : 0.00070329060 | Min Train Loss: 5.6716 | Min Val Loss : 5.8350 | Train Time : 0.19 hrs
# Final Validation Loss: 5.8350
# Final HellaSwag Accuracy: 0.2382
# Params: 6.9667840000m | LR : 0.00354518300 | Min Train Loss: 5.0264 | Min Val Loss : 5.1584 | Train Time : 0.19 hrs
# Final Validation Loss: 5.1584
# Final HellaSwag Accuracy: 0.2477
# Params: 6.9667840000m | LR : 0.01142674000 | Min Train Loss: 5.4779 | Min Val Loss : 5.6103 | Train Time : 0.19 hrs
# Final Validation Loss: 5.6103
# Final HellaSwag Accuracy: 0.2357
# Params: 6.9667840000m | LR : 0.00300000000 | Min Train Loss: 5.0770 | Min Val Loss : 5.2149 | Train Time : 0.19 hrs
# Final Validation Loss: 5.2149
# Final HellaSwag Accuracy: 0.2422
# Params: 6.9667840000m | LR : 0.00600000000 | Min Train Loss: 4.9386 | Min Val Loss : 5.0650 | Train Time : 0.19 hrs
# Final Validation Loss: 5.0650
# Final HellaSwag Accuracy: 0.2452
# Params: 6.9667840000m | LR : 0.00580000000 | Min Train Loss: 4.9418 | Min Val Loss : 5.0684 | Train Time : 0.19 hrs
# Final Validation Loss: 5.0684
# Final HellaSwag Accuracy: 0.2452
# Params: 6.9667840000m | LR : 0.00608000000 | Min Train Loss: 4.9281 | Min Val Loss : 5.0527 | Train Time : 0.19 hrs
# Final Validation Loss: 5.0527
# Final HellaSwag Accuracy: 0.2469

# %%
#TINY: Parameters: 111899520000  - LR : 0.00160431400
#TINIER: Parameters: 69667840000  - LR : 0.00622029800
#TINIEST: Parameters: 33351040000   - LR : 0.00639258600

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
params = np.array([11189952, 6966784, 3335104])
#learning_rates = np.array([0.001604314, 0.006220298, 0.006392586])
learning_rates = np.array([0.00613000000, 0.00608000000, 0.00600000000])
model_names = ['TINY', 'TINIER', 'TINIEST']

# Convert to log scale
log_params = np.log10(params)
log_lrs = np.log10(learning_rates)

# Fit linear regression in log-log space
coeffs = np.polyfit(log_params, log_lrs, 1)
slope, intercept = coeffs

# Define trend line function
def predict_lr(p):
    return 10**(slope * np.log10(p) + intercept)

# Predict for 124 million parameters
p_target = 124_000_000
predicted_lr = predict_lr(p_target)

# Plot
plt.figure(figsize=(6, 5))
plt.loglog(params, learning_rates, 'o', label='Data')
plt.loglog(params, 10**(slope * log_params + intercept), '--', label='Trend Line')

# Plot prediction point
plt.loglog(p_target, predicted_lr, 'rx', markersize=10, label=f'Predicted (124M): {predicted_lr:.10f}')

# Annotate original points
for i, name in enumerate(model_names):
    plt.text(params[i], learning_rates[i], f' {name}', fontsize=10, verticalalignment='bottom')

plt.xlabel("Number of Parameters")
plt.ylabel("Learning Rate")
plt.title("Log-Log Plot with Trend Line")
plt.grid(True, which="both", ls="--")
plt.legend()
plt.tight_layout()
plt.show()

print(f"Predicted learning rate at 124 million parameters: {predicted_lr:.6f}")
# Out:
# Predicted learning rate at 124 million parameters: 0.006398

# %% [markdown]
# Trail one: 0.5331
